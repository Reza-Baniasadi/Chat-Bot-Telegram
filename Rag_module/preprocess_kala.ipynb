# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv('/Users/mac/Documents/Chat-Bot-Telegram/DataSet/Kala/digikala-products.csv')
comment = pd.read_csv("/Users/mac/Documents/Chat-Bot-Telegram/DataSet/Kala/digikala-comments.csv")
data.head(2)
# Out:
# /var/folders/xn/9k_t21cj50q15j6t2z07zt640000gn/T/ipykernel_922/2269391988.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =pd.read_csv('/Users/mac/Documents/Chat-Bot-Telegram/DataSet/Kala/digikala-products.csv')
#         id                        title_fa  Rate  Rate_cnt Category1  \
# 0  7096438    آبسلانگ مدل s5 بسته 250 عددی    90         4   آبسلانگ
# 1  2845119   آبسلانگ مدل M-1 بسته 400 عددی    84       217   آبسلانگ
#
#   Category2   Brand   Price         Seller  Is_Fake  min_price_last_month  \
# 0       NaN  متفرقه  634800  سلامت ساز راد    False                     0
# 1       NaN  متفرقه  818800      مهر افزون    False                     0
#
#   sub_category
# 0       beauty
# 1       beauty

# %%
data.fillna(' ' , inplace=True)
comment.fillna(' ' , inplace=True)
#data.head(1)
comment.head(20)
# Out:
#           id                    title  \
# 0   53672599           پیشنهاد نمیشود
# 1    9897229             بسته بندی بد
# 2   38074516                 برس ریمل
# 3   18628562            خوبه و خوشرنگ
# 4   53301258               برس رنگ مو
# 5   53266157                     خوبه
# 6   46206235                بدک نیست
# 7   40597171           پد شستشوی براش
# 8   46198656                لنز ناخون
# 9   46901811                      خوب
# 10  20373536
# 11  40710017                     عالی
# 12  53791544
# 13  52495314                      خوب
# 14  34036284            قلم ماسک صورت
# 15  51783725             خیلی خوب بود
# 16  52776060  اصلا بدرد نمیخوره نخرید
# 17  52767482                 برس ابرو
# 18  48786928
# 19  25530926
#
#                                                  body        created_at  rate  \
# 0                                     به درد نمیخوره     23 شهریور 1402   1.0
# 1   می‌تونست به عنوان یه کالای فرهنگی بهتر بسته بن...       16 تیر 1399   0.0
# ...

# %%
data = data[data['Price'].notna()]
data['Price']
# Out:
# 0           634800
# 1           818800
# 2           920000
# 3          1100000
# 4          1530000
#             ...
# 1283491    2500000
# 1283492    2150000
# 1283493    2100000
# 1283494    2300000
# 1283495    2800000
# Name: Price, Length: 1283496, dtype: int64

# %%
def clean_text(data,column):
    data[column] = data[column].astype(str).str.lower()
    
clean_text(data,'title_fa')      
clean_text(comment,'body')      
clean_text(comment,'title')

# %%
data['text'] = " title product : "+ data['title_fa'] + ' Category1 ' + data['Category1'] + ' Category2 ' + data['Category2'] 

merge = pd.merge(data,comment,left_on='id',right_on='product_id',how='left')

merge['comment_text'] = (
    'id:' + merge['product_id'].astype(str) +
    'title : ' + merge['title'] +
    ' body : ' + merge['body'] +
    'rating :' + merge['rate'].astype(str)
)
#data['comment'] = merge['comment_text']

grouped_comment = merge.groupby('product_id')['comment_text'].apply(lambda x: " ".join(x)).reset_index()

data = pd.merge(data,grouped_comment, left_on='id' , right_on='product_id')

data.drop(columns='product_id',inplace=True)

data.fillna(' ' , inplace=True)


data.head(50)
# Out:
#           id                                           title_fa  Rate  \
# 0    7096438                       آبسلانگ مدل s5 بسته 250 عددی    90
# 1    2845119                      آبسلانگ مدل m-1 بسته 400 عددی    84
# 2    6117745                    آبسلانگ مدل m50 مجموعه 500 عددی    88
# 3    1912926                              استند ابسلانگ مدل s01    78
# 4    6335462                 آبسلانگ نوری تسلامد مدل all-in-one    84
# 5    6335562    سری آبسلانگ تسلامد مدل all-in-one بسته 100 عددی    80
# 6    7096725                     آبسلانگ مدل s20 بسته 1000 عددی    84
# 7    6005981                   استند آبسلانگ گلدن بیوتی مدل 01     84
# 8    4077287      آبسلانگ پل ایده آل پارس مدل td بسته 150 عددی     90
# 9   10179102                        آبسلانگ مدل a1 بسته 30 عددی    80
# 10   1743408                    آبسلانگ مدل 1006 مجموعه 10 عددی    68
# 11   3901016                        آبسلانگ مدل 01 بسته 50 عددی    78
# ...

# %%
merge.to_csv('kala.csv')
