# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset

# %%
model_name = "bert-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
dataset = load_dataset('json', data_files='/Users/mac/Documents/Chat-Bot-Telegram/dadrah_dataset1-100000_276342.json', split='train', streaming=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = load_dataset('json', data_files='/Users/mac/Documents/Chat-Bot-Telegram/dadrah_dataset1-100000_276342.json', split='train', streaming=True)
#
# File /usr/local/lib/python3.11/site-packages/datasets/load.py:1784, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    1782 # Return iterable dataset in case of streaming
#    1783 if streaming:
# -> 1784     return builder_instance.as_streaming_dataset(split=split)
#    1786 # Some datasets are already processed on the HF google storage
#    1787 # Don't try downloading from Google storage for the packaged datasets as text, json, csv or pandas
#    1788 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#
# File /usr/local/lib/python3.11/site-packages/datasets/builder.py:1253, in DatasetBuilder.as_streaming_dataset(self, split, base_path)
#    1251 is_local = not is_remote_filesystem(self._fs)
#    1252 if not is_local:
# -> 1253     raise NotImplementedError(
#    1254         f"Loading a streaming dataset cached in a {type(self._fs).__name__} is not supported yet."
#    1255     )
#    1257 dl_manager = StreamingDownloadManager(
#    1258     base_path=base_path or self.base_path,
#    1259     download_config=DownloadConfig(use_auth_token=self.use_auth_token, storage_options=self.storage_options),
#    1260     dataset_name=self.name,
#    1261     data_dir=self.config.data_dir,
#    1262 )
#    1263 self._check_manual_download(dl_manager)
#
# NotImplementedError: Loading a streaming dataset cached in a LocalFileSystem is not supported yet.
